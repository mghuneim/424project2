# %%
import pandas as pd

data = pd.read_excel('~/Downloads/egrid2018_historical_files_since_1996/eGRID2010_Data.xls', sheet_name = 'PLNT10')

# %%
data = data.iloc[4:]
data
# Out:
#      eGRID 9th edition Version 1.0 Plant File (Year 2010 Data) Unnamed: 1  \
# 4                                                     1                AK
# 5                                                     2                AK
# 6                                                     3                AK
# 7                                                     4                AK
# 8                                                     5                AK
# ...                                                 ...               ...
# 5586                                               5583                WY
# 5587                                               5584                WY
# 5588                                               5585                WY
# 5589                                               5586                WY
# 5590                                               5587                WY
#
#                       Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# ...

# %%
data2 = data[['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 81', 'Unnamed: 82', 'Unnamed: 83', 'Unnamed: 84', 'Unnamed: 85', 'Unnamed: 86', 'Unnamed: 87', 'Unnamed: 88', 'Unnamed: 89', 'Unnamed: 90', 'Unnamed: 91']]
data2
# Out:
#      Unnamed: 1                  Unnamed: 2 Unnamed: 20 Unnamed: 21  \
# 4            AK                    Alakanuk     62.6833   -164.6544
# 5            AK                 Anchorage 1     61.2328   -149.8909
# 6            AK                      Angoon     57.8425   -134.9772
# 7            AK                       Aniak     61.5875   -159.5317
# 8            AK                 Annex Creek     58.3167   -134.0958
# ...         ...                         ...         ...         ...
# 5586         WY                     Wygen 1     44.2862   -105.3843
# 5587         WY                     Wygen 2     44.2911   -105.3815
# 5588         WY                   Wygen III     44.2919   -105.3806
# 5589         WY                      Wyodak     44.2886   -105.3847
# 5590         WY  Wyoming Wind Energy Center     41.2874   -110.5556
#
#       Unnamed: 81 Unnamed: 82 Unnamed: 83 Unnamed: 84 Unnamed: 85 Unnamed: 86  \
# ...

# %%
data2['other'] = data2['Unnamed: 90'] + data2['Unnamed: 91']
# Out:
# <ipython-input-59-edfe74235714>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2['other'] = data2['Unnamed: 90'] + data2['Unnamed: 91']

# %%
del data2['Unnamed: 90']
del data2['Unnamed: 91']

data3 = data2.rename(columns={'Unnamed: 1': 'abb', 'Unnamed: 2': 'name', 'Unnamed: 20': 'lat', 'Unnamed: 21': 'long', 'Unnamed: 81': 'coal', 'Unnamed: 82': 'oil', 'Unnamed: 83': 'gas', 'Unnamed: 84': 'nuclear', 'Unnamed: 85': 'hydro', 'Unnamed: 86': 'bio', 'Unnamed: 87': 'wind', 'Unnamed: 75': 'solar', 'Unnamed: 76': 'geo'})
data3
# Out:
#      abb                              name      lat      long     coal  \
# 3     AK  AGRIUM KENAI NITROGEN OPERATIONS  60.0656  151.6719        0
# 4     AK                          ALAKANUK  60.2992  159.7343        0
# 5     AK                         ALLAKAKET  64.8557  146.2789        0
# 6     AK              ALYESKA SEAFOODS INC  51.9961  175.5654        0
# 7     AK                            AMBLER      NaN       NaN        0
# ...   ..                               ...      ...       ...      ...
# 4699  WY             SINCLAIR OIL REFINERY   41.717  106.9999        0
# 4700  WY                   SPIRIT MOUNTAIN  44.4095  109.8025        0
# 4701  WY                  STRAWBERRY CREEK  42.4468   110.546        0
# 4702  WY                     VIVA NAUGHTON  42.4468   110.546        0
# 4703  WY                            WYODAK  44.2833     105.4  2662685
#
#           oil       gas nuclear  hydro bio wind solar geo other
# ...

# %%
data3['long'] = -1 * data3['long']
data3
# Out:
#      abb                              name      lat      long     coal  \
# 3     AK  AGRIUM KENAI NITROGEN OPERATIONS  60.0656 -151.6719        0
# 4     AK                          ALAKANUK  60.2992 -159.7343        0
# 5     AK                         ALLAKAKET  64.8557 -146.2789        0
# 6     AK              ALYESKA SEAFOODS INC  51.9961 -175.5654        0
# 7     AK                            AMBLER      NaN       NaN        0
# ...   ..                               ...      ...       ...      ...
# 4699  WY             SINCLAIR OIL REFINERY   41.717 -106.9999        0
# 4700  WY                   SPIRIT MOUNTAIN  44.4095 -109.8025        0
# 4701  WY                  STRAWBERRY CREEK  42.4468  -110.546        0
# 4702  WY                     VIVA NAUGHTON  42.4468  -110.546        0
# 4703  WY                            WYODAK  44.2833    -105.4  2662685
#
#           oil       gas nuclear  hydro bio wind solar geo other
# ...

# %%
data3.to_csv('2000data.csv')
